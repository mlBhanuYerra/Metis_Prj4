# %%
# !pip install langdetect
# Out:
# ...
#      |████████████████████████████████| 1.0MB 4.6MB/s eta 0:00:01
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.7-cp37-none-any.whl size=993459 sha256=e13d11d58ad1eabbeb7e49f1a75ba4205e1b4a39c69ce3e246f221d29cc86f39
#   Stored in directory: /Users/bhanuyerra/Library/Caches/pip/wheels/ec/0c/a9/1647275e7ef5014e7b83ff30105180e332867d65e7617ddafe
# Successfully built langdetect
# ...

# %%
path = "Books_5.json"

fstream = open(path,"r")

count = 0
for line in fstream:
    if count<20:
        print(line)
        count += 1
    else:
        break
# Out:
# {"overall": 5.0, "verified": false, "reviewTime": "03 30, 2005", "reviewerID": "A1REUF3A1YCPHM", "asin": "0001713353", "style": {"Format:": " Hardcover"}, "reviewerName": "TW Ervin II", "reviewText": "The King, the Mice and the Cheese by Nancy Gurney is an excellent children's book.  It is one that I well remember from my own childhood and purchased for my daughter who loves it.\n\nIt is about a king who has trouble with rude mice eating his cheese. He consults his wise men and they suggest cats to chase away the mice. The cats become a nuisance, so the wise men recommend the king bring in dogs to chase the cats away.  The cycle goes on until the mice are finally brought back to chase away the elephants, brought in to chase away the lions that'd chased away the dogs.\n\nThe story ends in compromise and friendship between the mice and the king.  The story also teaches cause and effect relationships.\n\nThe pictures that accompany the story are humorous and memorable.  I was thrilled t
# ...

# %%
path = "book_data.csv"
fstream = open(path,"r")

import pandas as pd


count = 0
for line in fstream:
    if count<20:
        print(line)
        count += 1
    else:
        break
# Out:
# book_authors,book_desc,book_edition,book_format,book_isbn,book_pages,book_rating,book_rating_count,book_review_count,book_title,genres,image_url
#
# ...

# %%
import pandas as pd

path = "book_data.csv"
book_df = pd.read_csv(path)
book_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54301 entries, 0 to 54300
# Data columns (total 12 columns):
# book_authors         54301 non-null object
# book_desc            52970 non-null object
# book_edition         5453 non-null object
# book_format          52645 non-null object
# book_isbn            41435 non-null object
# book_pages           51779 non-null object
# book_rating          54301 non-null float64
# book_rating_count    54301 non-null int64
# book_review_count    54301 non-null int64
# book_title           54301 non-null object
# genres               51059 non-null object
# image_url            53618 non-null object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 5.0+ MB

# %%
book_df.dropna()
book_df.head(20)
# Out:
#                                          book_authors  \
# 0                                     Suzanne Collins
# 1                          J.K. Rowling|Mary GrandPré
# 2                                          Harper Lee
# 3   Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                     Stephenie Meyer
# 5                                        Markus Zusak
# 6                           C.S. Lewis|Pauline Baynes
# 7                                       George Orwell
# 8                                   Margaret Mitchell
# 9                                      J.R.R. Tolkien
# 10                                         John Green
# 11                                      Douglas Adams
# 12                                   Shel Silverstein
# 13  Emily Brontë|Richard J. Dunn|David Timson|Char...
# 14                                          Dan Brown
# 15                                      Arthur Golden
# ...

# %%
from langdetect import DetectorFactory 
DetectorFactory.seed = 0

# %%
from langdetect import detect
#book_df["language"] = book_df["book_desc"].apply(detect)
print(detect(book_df.iloc[7]["book_desc"]))
book_df.iloc[13]["book_desc"]
# Out:
# ar
# ...

# %%
amxnBooks = ""
